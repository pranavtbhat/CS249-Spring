// %%
import org.apache.spark.sql.types._
import org.apache.spark.sql.ForeachWriter
import org.apache.spark.sql.catalyst.ScalaReflection
import org.apache.spark.sql.Row
import org.apache.spark.sql.functions._
import org.apache.spark.sql.SQLContext

val sqlContext = new SQLContext(sc)
import sqlContext.implicits._

// %%
case class Tweet(text : String)

var schema = ScalaReflection.schemaFor[Tweet].dataType.asInstanceOf[StructType]

// %%
var streamTweets = spark.readStream.
    schema(schema).
    csv("tweets/")

// %%
streamTweets.
    reservoir(5).
    writeStream.
    format("console").
    outputMode("update").
    start
// Out:
// org.apache.spark.sql.execution.streaming.StreamingQueryWrapper@6999a8d7
// -------------------------------------------
// Batch: 0
// -------------------------------------------
// +----+
// |text|
// +----+
// +----+
//
// -------------------------------------------
// Batch: 1
// -------------------------------------------
// +--------------------+
// |                text|
// +--------------------+
// |RT @Umnia77: Pak ...|
// |RT @mykaljackson4...|
// |Trump sale de acu...|
// |RT @mike4193496: ...|
// |RT @laynier: It w...|
// +--------------------+
//
// -------------------------------------------
// Batch: 2
// -------------------------------------------
// +--------------------+
// |                text|
// +--------------------+
// |RT @SafetyPinDail...|
// |meganamram Congra...|
// |@TheDukeMSR donal...|
// |@realDonaldTrump ...|
// |#trump Scarier th...|
// +--------------------+
//
// -------------------------------------------
// Batch: 3
// -------------------------------------------
// +--------------------+
// |                text|
// +--------------------+
// |RT @joncoopertwee...|
// |RT @TruthFeedNews...|
// |RT @misterscharf:...|
// |RT @ABC: London M...|
// |RT @LOLGOP: Trump...|
// +--------------------+
//
// -------------------------------------------
// Batch: 4
// -------------------------------------------
// +--------------------+
// |                text|
// +--------------------+
// |Also frankly if t...|
// |RT @joncoopertwee...|
// |RT @lizzieohreall...|
// |@mrbonge @emiland...|
// |RT @CNNPolitics: ...|
// +--------------------+
//
// -------------------------------------------
// Batch: 5
// -------------------------------------------
// +--------------------+
// |                text|
// +--------------------+
// |RT @DonaldJTrumpJ...|
// |RT @LaHojillaenTV...|
// |RT @TeaPainUSA: R...|
// |MSNBC Anchor Wond...|
// |@FoxNews @VP Only...|
// +--------------------+
//
// -------------------------------------------
// Batch: 6
// -------------------------------------------
// +--------------------+
// |                text|
// +--------------------+
// |RT @CoryBooker: T...|
// |RT @CNN: Rep. Smi...|
// |Intelligence Cont...|
// |Intelligence Cont...|
// |Like Chelsea Manning|
// +--------------------+
//
// -------------------------------------------
// Batch: 7
// -------------------------------------------
// +--------------------+
// |                text|
// +--------------------+
// |RT @TeaPainUSA: T...|
// |RT @DumpTrump22: ...|
// |RT @PinkBelgium: ...|
// |RT @fr_pwest: Les...|
// |RT @bradheath: Ea...|
// +--------------------+
//
// -------------------------------------------
// Batch: 8
// -------------------------------------------
// +--------------------+
// |                text|
// +--------------------+
// |RT @TeresaEdelgla...|
// |RT @Srsantti: Com...|
// |RT @mmurraypoliti...|
// |@SocialPowerOne1 ...|
// |Worse. Yes. https...|
// +--------------------+
//
// -------------------------------------------
// Batch: 9
// -------------------------------------------
// +--------------------+
// |                text|
// +--------------------+
// |RT @LouiseMensch:...|
// |RT @WorldfNature:...|
// |RT @kwilli1046: F...|
// |RT @Adel__Almalki...|
// |RT @ShaunKing: Ag...|
// +--------------------+
//
// -------------------------------------------
// Batch: 10
// -------------------------------------------
// +--------------------+
// |                text|
// +--------------------+
// |RT @MrTommyCampbe...|
// |RT @adamgoldmanNY...|
// |@szaman @TuckerCa...|
// |RT @sheriffali: T...|
// |RT @politico: Is ...|
// +--------------------+
//
// -------------------------------------------
// Batch: 11
// -------------------------------------------
// +--------------------+
// |                text|
// +--------------------+
// |RT @BreitbartNews...|
// |Putin See Coconut...|
// |RT @RobbieGramer:...|
// |RT @DBloom451: Ha...|
// |RT @davidsirota: ...|
// +--------------------+
//
// -------------------------------------------
// Batch: 12
// -------------------------------------------
// +--------------------+
// |                text|
// +--------------------+
// |RT @HRLori: ❤️ ht...|
// |#Thefive but the ...|
// |RT @funder: Donal...|
// |RT @gunsdownameri...|
// |RT @Broadsword_6:...|
// +--------------------+
//
// -------------------------------------------
// Batch: 13
// -------------------------------------------
