// %%
import org.apache.spark.sql.types._
import org.apache.spark.sql.ForeachWriter
import org.apache.spark.sql.catalyst.ScalaReflection
import org.apache.spark.sql.Row
import org.apache.spark.sql.functions._
import org.apache.spark.sql.SQLContext

val sqlContext = new SQLContext(sc)
import sqlContext.implicits._

// %%
case class Entry(distType : String, num : Float)

var schema = ScalaReflection.schemaFor[Entry].dataType.asInstanceOf[StructType]

// %%
var streamUniform = spark.readStream.
    schema(schema).
    csv("dist/")

// %%
streamUniform.reservoir(100).groupBy("distType").agg(avg($"num")).writeStream.format("console").outputMode("update").start
// Out:
// org.apache.spark.sql.execution.streaming.StreamingQueryWrapper@1ccabd0f
// -------------------------------------------
// Batch: 0
// -------------------------------------------
// +----------+-------------------+
// |  distType|           avg(num)|
// +----------+-------------------+
// |    Power | 0.7342847563602306|
// |   Normal |0.49904702231287956|
// |Geometric | 3.2916666666666665|
// |  Uniform | 0.4700910151004791|
// +----------+-------------------+
//
// -------------------------------------------
// Batch: 1
// -------------------------------------------
// +----------+-------------------+
// |  distType|           avg(num)|
// +----------+-------------------+
// |    Power | 0.6863256593545278|
// |   Normal |0.49713969622787674|
// |Geometric | 3.0795454545454546|
// |  Uniform |0.45085576749764955|
// +----------+-------------------+
//
// -------------------------------------------
// Batch: 2
// -------------------------------------------
// +----------+------------------+
// |  distType|          avg(num)|
// +----------+------------------+
// |   Normal |0.5014303034543991|
// |    Power |0.7497233615981208|
// |Geometric | 3.051851851851852|
// |  Uniform |0.4889327462600625|
// +----------+------------------+
//
// -------------------------------------------
// Batch: 3
// -------------------------------------------
// +----------+-------------------+
// |  distType|           avg(num)|
// +----------+-------------------+
// |   Normal |0.48449427085918384|
// |    Power | 0.7564212272222015|
// |Geometric | 3.0451612903225804|
// |  Uniform | 0.5050968461837925|
// +----------+-------------------+
//
// -------------------------------------------
// Batch: 4
// -------------------------------------------
// +----------+------------------+
// |  distType|          avg(num)|
// +----------+------------------+
// |    Power |0.7328603143914271|
// |   Normal |0.4931910216808319|
// |Geometric |3.0419161676646707|
// |  Uniform |0.4668071969892039|
// +----------+------------------+
//
// -------------------------------------------
// Batch: 5
// -------------------------------------------
// +----------+-------------------+
// |  distType|           avg(num)|
// +----------+-------------------+
// |   Normal |0.49086488968264447|
// |    Power | 0.7406217811363084|
// |Geometric | 3.2941176470588234|
// |  Uniform | 0.4595997351866502|
// +----------+-------------------+
//
// -------------------------------------------
// Batch: 6
// -------------------------------------------
// +----------+-------------------+
// |  distType|           avg(num)|
// +----------+-------------------+
// |   Normal |0.49683956340042473|
// |    Power | 0.7340330220548447|
// |Geometric | 3.2777777777777777|
// |  Uniform |  0.449754062435917|
// +----------+-------------------+
//
// -------------------------------------------
// Batch: 7
// -------------------------------------------
// +----------+-------------------+
// |  distType|           avg(num)|
// +----------+-------------------+
// |    Power | 0.7520944460136134|
// |   Normal |0.49366632192882137|
// |Geometric |  3.272277227722772|
// |  Uniform |0.44191688537517543|
// +----------+-------------------+
//
// -------------------------------------------
// Batch: 8
// -------------------------------------------
// +----------+-------------------+
// |  distType|           avg(num)|
// +----------+-------------------+
// |   Normal |0.49596057924223536|
// |    Power | 0.7456573900409732|
// |Geometric |  3.259433962264151|
// |  Uniform | 0.4353036141585348|
// +----------+-------------------+
//
// -------------------------------------------
// Batch: 9
// -------------------------------------------
// +----------+------------------+
// |  distType|          avg(num)|
// +----------+------------------+
// |   Normal | 0.479766872150219|
// |    Power |0.7487459848692388|
// |Geometric |3.2455357142857144|
// |  Uniform |0.4475011101199521|
// +----------+------------------+
//
// -------------------------------------------
// Batch: 10
// -------------------------------------------
// +----------+------------------+
// |  distType|          avg(num)|
// +----------+------------------+
// |   Normal |0.4809908784048075|
// |    Power |0.7406867362339707|
// |Geometric |3.2401746724890828|
// |  Uniform |0.4697348933155073|
// +----------+------------------+
//
// -------------------------------------------
// Batch: 11
// -------------------------------------------
// +----------+------------------+
// |  distType|          avg(num)|
// +----------+------------------+
// |   Normal |0.4849401586603049|
// |    Power |0.7455704540726268|
// |Geometric |            3.3625|
// |  Uniform |0.4785351370533941|
// +----------+------------------+
//
// -------------------------------------------
// Batch: 12
// -------------------------------------------
// +----------+-------------------+
// |  distType|           avg(num)|
// +----------+-------------------+
// |    Power | 0.7540037245728818|
// |   Normal |0.48279694336519646|
// |Geometric | 3.3493975903614457|
// |  Uniform | 0.4847012040867108|
// +----------+-------------------+
//
// -------------------------------------------
// Batch: 13
// -------------------------------------------
// +----------+-------------------+
// |  distType|           avg(num)|
// +----------+-------------------+
// |   Normal | 0.4834622734404625|
// |    Power | 0.7560744537941871|
// |Geometric | 3.3411764705882354|
// |  Uniform |0.48448289180347737|
// +----------+-------------------+
//
// -------------------------------------------
// Batch: 14
// -------------------------------------------
// +----------+-------------------+
// |  distType|           avg(num)|
// +----------+-------------------+
// |    Power | 0.7613115334794635|
// |   Normal |0.48373187745788265|
// |Geometric | 3.3346153846153848|
// |  Uniform | 0.4998828261744618|
// +----------+-------------------+
//
// -------------------------------------------
// Batch: 15
// -------------------------------------------
// +----------+-------------------+
// |  distType|           avg(num)|
// +----------+-------------------+
// |   Normal |0.48608128244478654|
// |    Power | 0.7642844599147031|
// |Geometric | 3.3295454545454546|
// |  Uniform | 0.4896804139970389|
// +----------+-------------------+
//
// -------------------------------------------
// Batch: 16
// -------------------------------------------
// +----------+------------------+
// |  distType|          avg(num)|
// +----------+------------------+
// |   Normal | 0.489251411327767|
// |    Power |0.7653606324351883|
// |Geometric |3.4721189591078065|
// |  Uniform |0.4915685453021002|
// +----------+------------------+
//
// -------------------------------------------
// Batch: 17
// -------------------------------------------
// +----------+------------------+
// |  distType|          avg(num)|
// +----------+------------------+
// |   Normal |0.4866215638179318|
// |    Power |0.7576525527947595|
// |Geometric |3.4652014652014653|
// |  Uniform |0.4853358645824359|
// +----------+------------------+
//
// -------------------------------------------
// Batch: 18
// -------------------------------------------
// +----------+-------------------+
// |  distType|           avg(num)|
// +----------+-------------------+
// |   Normal |0.48485888564314283|
// |    Power | 0.7570047484168524|
// |Geometric | 3.5638297872340425|
// |  Uniform |0.48272291862842986|
// +----------+-------------------+
//
// -------------------------------------------
// Batch: 19
// -------------------------------------------
// +----------+-------------------+
// |  distType|           avg(num)|
// +----------+-------------------+
// |    Power | 0.7585586949230682|
// |   Normal | 0.4878127872943878|
// |Geometric |  3.550173010380623|
// |  Uniform |0.48921329994808954|
// +----------+-------------------+
//
// -------------------------------------------
// Batch: 20
// -------------------------------------------
// +----------+------------------+
// |  distType|          avg(num)|
// +----------+------------------+
// |    Power |0.7562495429976648|
// |   Normal |0.4888415139941455|
// |Geometric |3.5371621621621623|
// |  Uniform |0.4876724119924566|
// +----------+------------------+
//
// -------------------------------------------
// Batch: 21
// -------------------------------------------
// +----------+-------------------+
// |  distType|           avg(num)|
// +----------+-------------------+
// |    Power | 0.7615354844886074|
// |   Normal |0.48896537041806676|
// |Geometric |  3.528239202657807|
// |  Uniform | 0.4910136504217392|
// +----------+-------------------+
//
// -------------------------------------------
// Batch: 22
// -------------------------------------------
// +----------+------------------+
// |  distType|          avg(num)|
// +----------+------------------+
// |    Power |0.7568995074291062|
// |   Normal |0.4883768947491812|
// |Geometric | 3.519607843137255|
// |  Uniform |0.4917119157790945|
// +----------+------------------+
//
// -------------------------------------------
// Batch: 23
// -------------------------------------------
// +----------+-------------------+
// |  distType|           avg(num)|
// +----------+-------------------+
// |   Normal |0.48955112328382433|
// |    Power | 0.7554850205055719|
// |Geometric | 3.5145631067961167|
// |  Uniform | 0.4863291817960831|
// +----------+-------------------+
//
// -------------------------------------------
// Batch: 24
// -------------------------------------------
// +----------+-------------------+
// |  distType|           avg(num)|
// +----------+-------------------+
// |    Power | 0.7509696353714503|
// |   Normal |0.48836320109905734|
// |Geometric | 3.5474683544303796|
// |  Uniform | 0.4834898840524812|
// +----------+-------------------+
//
// -------------------------------------------
// Batch: 25
// -------------------------------------------
// +----------+-------------------+
// |  distType|           avg(num)|
// +----------+-------------------+
// |    Power | 0.7557304151680159|
// |   Normal |0.48913156752567977|
// |Geometric |  3.545741324921136|
// |  Uniform |0.48720750776830773|
// +----------+-------------------+
//
// -------------------------------------------
// Batch: 26
// -------------------------------------------
// +----------+------------------+
// |  distType|          avg(num)|
// +----------+------------------+
// |    Power |0.7548899429698362|
// |   Normal |0.4902294142546107|
// |Geometric |3.6137071651090342|
// |  Uniform |0.4851679840026288|
// +----------+------------------+
//
// -------------------------------------------
// Batch: 27
// -------------------------------------------
// +----------+-------------------+
// |  distType|           avg(num)|
// +----------+-------------------+
// |    Power |  0.751758375404153|
// |   Normal |  0.490457893694629|
// |Geometric | 3.6439628482972135|
// |  Uniform |0.49194952761897004|
// +----------+-------------------+
//
// -------------------------------------------
// Batch: 28
// -------------------------------------------
// +----------+-------------------+
// |  distType|           avg(num)|
// +----------+-------------------+
// |    Power | 0.7522843489092569|
// |   Normal |0.49177949546381483|
// |Geometric | 3.6625766871165646|
// |  Uniform | 0.4909585200896336|
// +----------+-------------------+
//
// -------------------------------------------
// Batch: 29
// -------------------------------------------
// +----------+------------------+
// |  distType|          avg(num)|
// +----------+------------------+
// |   Normal |0.4909384109383255|
// |    Power |0.7514619349326143|
// |Geometric |3.6656534954407296|
// |  Uniform |0.4883975758795911|
// +----------+------------------+
//
// -------------------------------------------
// Batch: 30
// -------------------------------------------
// +----------+-------------------+
// |  distType|           avg(num)|
// +----------+-------------------+
// |   Normal |0.49142629937993154|
// |    Power | 0.7488790707928794|
// |Geometric | 3.6596385542168677|
// |  Uniform | 0.4914483964736017|
// +----------+-------------------+
//
// -------------------------------------------
// Batch: 31
// -------------------------------------------
// +----------+-------------------+
// |  distType|           avg(num)|
// +----------+-------------------+
// |   Normal |0.49105178826564067|
// |    Power |  0.750337542537546|
// |Geometric |  3.719402985074627|
// |  Uniform | 0.4900588610043031|
// +----------+-------------------+
//
// -------------------------------------------
// Batch: 32
// -------------------------------------------
// +----------+------------------+
// |  distType|          avg(num)|
// +----------+------------------+
// |   Normal |0.4905807646222351|
// |    Power |0.7533956561865431|
// |Geometric |3.8181818181818183|
// |  Uniform |0.4917969122308641|
// +----------+------------------+
//
// -------------------------------------------
// Batch: 33
// -------------------------------------------
// +--------+-------------------+
// |distType|           avg(num)|
// +--------+-------------------+
// |  Power | 0.7557978270382717|
// | Normal |0.49174137026071546|
// |Uniform | 0.4911980663434055|
// +--------+-------------------+
//
// -------------------------------------------
// Batch: 34
// -------------------------------------------
// +----------+------------------+
// |  distType|          avg(num)|
// +----------+------------------+
// |   Normal |0.4919422578397405|
// |    Power |0.7538140479875225|
// |Geometric |3.8157894736842106|
// |  Uniform |0.4878741229820292|
// +----------+------------------+
//
// -------------------------------------------
// Batch: 35
// -------------------------------------------
// +----------+-------------------+
// |  distType|           avg(num)|
// +----------+-------------------+
// |    Power | 0.7522521663038978|
// |   Normal | 0.4916173696797778|
// |Geometric |   3.80635838150289|
// |  Uniform |0.48810242615066335|
// +----------+-------------------+
//
// -------------------------------------------
// Batch: 36
// -------------------------------------------
